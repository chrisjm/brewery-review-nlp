# %% [markdown]
# # [San Diego Brewers Guild](https://www.sdbeer.com)
#
# This is a notebook to scrape websites for data and export as CSV

# %%
import requests
import folium
import numpy as np
from folium import plugins
from bs4 import BeautifulSoup

# %%
# Get the page and parse
url = "https://www.sdbeer.com/breweries"
page = requests.get(url)
soup = BeautifulSoup(page.text)

# %%
# Select all of the brewery items
items = soup.select('div.grid.block-4 .item')
print(f"There are {len(items)} breweries listed at {url}.")
# Out:
# There are 126 breweries listed at https://www.sdbeer.com/breweries.

# %%
# Create a list of dictionaries
breweries = []

for brewery in items:
    name = brewery.find('a')['aria-label']
    brewery_path = brewery.find('a')['href']
    logo_url = brewery.find('img')['src']
    breweries.append({'name': name, 'website_url': url + brewery_path, 'logo_url': logo_url})
                     
print(f"{len(breweries)} breweries found and added to our list.")
# Out:
# 126 breweries found and added to our list.

# %%
from pathlib import Path

# Download logos, if they don't already exist
print("Downloading new logos...")
for brewery in breweries:
    image_file_path = Path(f"data/logos/CA - San Diego - {brewery['name']}.png")
    
    # Don't download logos we already have     
    if not image_file_path.is_file():
        r = requests.get(brewery['logo_url'])
        file = open(image_file_path, "wb")
        file.write(r.content)
        file.close()
        print("Downloaded {image_file_path}")
        
print("Complete!")
# Out:
# Downloading new logos...
# Complete!

# %%
# Select the first brewery and GET the page
brewery = breweries[0]
r = requests.get(brewery['website_url'])

# %%
# SD Brewer's Guild is using Next.js
soup = BeautifulSoup(r.content)
# Get all of the <script> tags and verify the number of <script> tags
scripts = soup.find_all('script')
# Verify length of the first one (~510k)
len(scripts[0].contents[0])
# Out:
# 506507

# %%
import re

# We're only interested in the first script tag
contents = str(scripts[0].contents[0])
# Create a pattern to look for the Next.js data variable
pattern = r"__NEXT_DATA__ = ({.*};)"
# Create a Match object and verify the length of the match (~510k)
next_data = re.match(pattern, contents)
# Verify the length of the group (~510k, but less than above)
len(next_data.group(1))
# Out:
# 506396

# %%
import json

# Parse as JSON, but omit the semi-colon
json_parsed = json.loads(next_data.group(1)[:-1])

# Good for inspection
# print(json.dumps(json_parsed, indent=4, sort_keys=True))

# Drill down to grab the breweries
breweries_list = json_parsed["props"]["initialState"]["sdbgBreweries"]["list"]['_list']

# Determine number of locations
locations = 0
for brewery in breweries_list:
    for location in brewery['locations']:
        locations += 1

print(f"Scraped {len(breweries_list)} breweries and {locations} locations.")
# Out:
# Scraped 165 breweries and 430 locations.

# %%
from pprint import PrettyPrinter

# Pretty print for verification
pp = PrettyPrinter()
pp.pprint(breweries_list[:3])
# Out:
# [{'_id': '5a822075b9cee17a0adff28e',
#   'betterpress': True,
#   'created': 1468282975000,
#   'deactivated': False,
#   'facebook': 'https://www.facebook.com/southparkbrewco',
#   'image': 'https://s3-us-west-1.amazonaws.com/paradeigm-social/qJzF6dQmTQukygOMI1Bk_SP '
#            'brewing.png',
#   'instagram': 'https://www.instagram.com/southparkbrewco/',
#   'locations': [{'_id': '5a8bb1df1c05c867bedca3e7',
#                  'betterpress': True,
#                  'brewery': None,
#                  'breweryUuid': 'WyBROCGvMw52',
#                  'city': 'San Diego',
#                  'coords': [-117.1301127, 32.7216668],
#                  'country': 'US',
#                  'events': None,
#                  'lat': 32.7216668,
#                  'lng': -117.1301127,
#                  'name': 'South Park Brewing Company',
#                  'profileLocation': True,
#                  'state': 'CA',
#                  'street': '1517 30th St',
#                  'tags': {'dogFriendly': True,
#                           'familyFriendly': True,
#                           'foodService': True,
#                           'foodTrucks': False,
#                           'growlerFills': True,
#                           'over21': False},
#                  'uuid': 'fWoiLFXw7k82'}],
#   'name': 'South Park Brewing Company',
#   'twitter': 'https://twitter.com/SouthParkBrewCo',
#   'type': 'brewery',
#   'untappdId': '189064',
#   'uuid': 'WyBROCGvMw52',
#   'visible': True,
#   'website': 'http://www.southparkbrewing.com/'},
#  {'_id': '5a822075b9cee17a0adff2a7',
#   'betterpress': True,
#   'created': 1485381102000,
#   'deactivated': False,
#   'facebook': 'https://www.facebook.com/rouleurbrewing',
#   'image': 'https://s3-us-west-1.amazonaws.com/sdbeer2/llbJE9RR1mmPXP7Xbh4w',
#   'instagram': 'https://www.instagram.com/rouleurbrewing/',
#   'locations': [{'_id': '5a822074b9cee17a0adff208',
#                  'betterpress': True,
#                  'brewery': None,
#                  'breweryUuid': 'mq5pOQdvyAmg',
#                  'city': 'Carlsbad',
#                  'coords': [-117.2698102, 33.1344625],
#                  'country': 'US',
#                  'events': None,
#                  'lat': 33.1344625,
#                  'lng': -117.2698102,
#                  'name': 'Rouleur Brewing Company',
#                  'profileLocation': True,
#                  'state': 'CA',
#                  'street': '5840 El Camino Real, Suite 101',
#                  'tags': {'dogFriendly': True,
#                           'familyFriendly': True,
#                           'foodService': False,
#                           'foodTrucks': True,
#                           'growlerFills': True,
#                           'over21': False},
#                  'uuid': 'YX3a9mqutIyJ'},
#                 {'_id': '5dbca10e02874800142d8574',
#                  'brewery': None,
#                  'breweryUuid': 'mq5pOQdvyAmg',
#                  'city': 'Carlsbad ',
#                  'coords': [-117.260355, 33.1281963],
#                  'events': None,
#                  'lat': 33.1281963,
#                  'lng': -117.260355,
#                  'name': 'Carlsbad Brewing Company',
#                  'profileLocation': False,
#                  'state': 'CA',
#                  'street': '6133 Innovation Way',
#                  'uuid': 'f0d431151cefd0656985'},
#                 {'_id': '5dbcaa3791bfa500141a7fa6',
#                  'brewery': None,
#                  'breweryUuid': 'mq5pOQdvyAmg',
#                  'city': 'Escondido',
#                  'coords': [-117.0792423, 33.1226102],
#                  'events': None,
#                  'lat': 33.1226102,
#                  'lng': -117.0792423,
#                  'name': 'Burger Bench',
#                  'profileLocation': False,
#                  'state': 'CA',
#                  'street': '237 E. Grand Ave',
#                  'uuid': '67a39238060da37c2b71'},
#                 {'_id': '5dbcb12d5df5320014f3e4aa',
#                  'brewery': None,
#                  'breweryUuid': 'mq5pOQdvyAmg',
#                  'city': 'Carlsbad ',
#                  'coords': [-117.3107141, 33.132775],
#                  'events': None,
#                  'lat': 33.132775,
#                  'lng': -117.3107141,
#                  'name': '7 Mile Kitchen',
#                  'profileLocation': False,
#                  'state': 'CA',
#                  'street': '5420 Grand Pacific Dr',
#                  'uuid': '2f7bf12b36917ce15e71'}],
#   'name': 'Rouleur Brewing Company',
#   'twitter': 'https://twitter.com/rouleurbrewing',
#   'type': 'brewery',
#   'untappdId': '332529',
#   'uuid': 'mq5pOQdvyAmg',
#   'visible': True,
#   'website': 'http://rouleurbrewing.com/'},
#  {'_id': '5a822075b9cee17a0adff2d4',
#   'betterpress': True,
#   'created': 1423170083000,
#   'deactivated': False,
#   'facebook': 'https://www.facebook.com/thornstreetbrew',
#   'image': 'https://s3-us-west-1.amazonaws.com/sdbeer2/oDP478cTHwTGN7PpzCrQ',
#   'instagram': 'https://www.instagram.com/thornstreetbrewery',
#   'locations': [{'_id': '5a822075b9cee17a0adff254',
#                  'betterpress': True,
#                  'brewery': None,
#                  'breweryUuid': 'iEulEhPtjS6G',
#                  'city': 'San Diego',
#                  'coords': [-117.1479369, 32.702261],
#                  'country': 'US',
#                  'events': None,
#                  'lat': 32.702261,
#                  'lng': -117.1479369,
#                  'name': 'Thorn Brewing Co. - Barrio Logan',
#                  'profileLocation': True,
#                  'state': 'CA',
#                  'street': '1735 National Avenue',
#                  'tags': {'dogFriendly': True,
#                           'familyFriendly': True,
#                           'foodService': False,
#                           'foodTrucks': True,
#                           'growlerFills': True,
#                           'over21': False},
#                  'uuid': 'n5L36Pk0TXGW'},
#                 {'_id': '5a822075b9cee17a0adff253',
#                  'betterpress': True,
#                  'brewery': None,
#                  'breweryUuid': 'iEulEhPtjS6G',
#                  'city': 'San Diego',
#                  'coords': [-117.1254989, 32.7393987],
#                  'country': 'US',
#                  'events': None,
#                  'lat': 32.7393987,
#                  'lng': -117.1254989,
#                  'name': 'Thorn Street Brewery',
#                  'profileLocation': True,
#                  'state': 'CA',
#                  'street': '3176 Thorn Street',
#                  'tags': {'dogFriendly': True,
#                           'familyFriendly': True,
#                           'foodService': False,
#                           'foodTrucks': True,
#                           'growlerFills': True,
#                           'over21': False},
#                  'uuid': '3nODo4jCM1xD'},
#                 {'_id': '5ab276f66b0f5b0014f2c6d2',
#                  'betterpress': True,
#                  'brewery': None,
#                  'breweryUuid': 'iEulEhPtjS6G',
#                  'city': 'San Diego',
#                  'coords': [-117.2123081, 32.7551821],
#                  'country': 'US',
#                  'deactivated': True,
#                  'events': None,
#                  'lat': 32.7551821,
#                  'lng': -117.2123081,
#                  'name': 'Valley View Casino Center',
#                  'profileLocation': False,
#                  'state': 'CA',
#                  'street': '3500 Sports Arena Boulevard',
#                  'tags': {'dogFriendly': False,
#                           'familyFriendly': False,
#                           'foodService': False,
#                           'foodTrucks': False,
#                           'growlerFills': False,
#                           'over21': False},
#                  'uuid': 'eOC45gHL42Oa'},
#                 {'_id': '5c795efa9162f10014a85553',
#                  'brewery': None,
#                  'breweryUuid': 'iEulEhPtjS6G',
#                  'city': 'San Diego',
#                  'coords': [-117.212196, 32.755274],
#                  'events': None,
#                  'lat': 32.755274,
#                  'lng': -117.212196,
#                  'name': 'Pechanga Arena San Diego',
#                  'profileLocation': False,
#                  'state': ' CA ',
#                  'street': '3500 Sports Arena Blvd, 3500 Sports Arena Blvd',
#                  'uuid': '088ca3ef0a55c94bf858'},
#                 {'_id': '5cd3432028427d0014253955',
#                  'brewery': None,
#                  'breweryUuid': 'iEulEhPtjS6G',
#                  'city': 'San Diego',
#                  'coords': [-117.1725897, 32.7504106],
#                  'events': None,
#                  'lat': 32.7504106,
#                  'lng': -117.1725897,
#                  'name': 'Thorn Brewing Co. - Mission Hills  ',
#                  'profileLocation': True,
#                  'state': 'CA',
#                  'street': '4026 Hawk St Suite A',
#                  'tags': {'dogFriendly': True,
#                           'familyFriendly': True,
#                           'growlerFills': True},
#                  'uuid': 'b923aec41352ad855fcf'}],
#   'name': 'Thorn Brewing Co.',
#   'twitter': 'https://twitter.com/ThornStBrewery',
#   'type': 'brewery',
#   'untappdId': '47013',
#   'uuid': 'iEulEhPtjS6G',
#   'visible': True,
#   'website': 'http://thorn.beer'}]

# %%
# Now that we have ALL of the breweries, let's recompile the breweries
breweries = []

for brewery in breweries_list:
    for location in brewery['locations']:
        tag_dogFriendly = False
        tag_familyFriendly = False
        tag_foodService = False
        tag_foodTrucks = False
        tag_growlerFills = False
        tag_over21 = False
        if location.get('tags', False):
            tags = location['tags']
            tag_dogFriendly = tags.get('dogFriendly', False)
            tag_familyFriendly = tags.get('familyFriendly', False)
            tag_foodService = tags.get('foodService', False)
            tag_foodTrucks = tags.get('foodTrucks', False)
            tag_growlerFills = tags.get('growlerFills', False)
            tag_over21 = tags.get('over21', False)
        new_brewery = {
            'name_brewery': brewery['name'],
            'name_location': location['name'],
            'social_twitterUrl': brewery.get('twitter', ''),
            'social_facebookUrl': brewery.get('facebook', ''),
            'social_instagramUrl': brewery.get('instagram', ''),
            'social_untappdId': brewery.get('untappdId', ''),
            'lat': location['lat'],
            'lng': location['lng'],
            'coords': location['coords'],
            'street': location['street'],
            'city': location['city'],
            'state': 'California',
            'country': 'US',
            'brewery_type': brewery['type'],
            'visible': brewery.get('visible', False),
            'deactivated': brewery.get('deactivated', True),
            'created': brewery['created'],
            'website': brewery['website'],
            'uuid': brewery['uuid'],
            'logo_url': brewery['image'], 
            'profile_location': location.get('profileLocation', False),
            'tag_dogFriendly': tag_dogFriendly,
            'tag_familyFriendly': tag_familyFriendly,
            'tag_foodService': tag_foodService,
            'tag_foodTrucks': tag_foodTrucks,
            'tag_growlerFills': tag_growlerFills,
            'tag_over21': tag_over21
        }
        breweries.append(new_brewery)
    
print(f"{len(breweries)} brewery locations processed.")
# Out:
# 430 brewery locations processed.

# %%
import pandas as pd

df = pd.DataFrame(breweries)
df
# Out:
#                          name_brewery                  name_location  \
# 0          South Park Brewing Company     South Park Brewing Company
# 1             Rouleur Brewing Company        Rouleur Brewing Company
# 2             Rouleur Brewing Company       Carlsbad Brewing Company
# 3             Rouleur Brewing Company                   Burger Bench
# 4             Rouleur Brewing Company                 7 Mile Kitchen
# ..                                ...                            ...
# 425              TapRoom Beer Company           TapRoom Beer Company
# 426                Five Suits Brewing             Five Suits Brewing
# 427       Groundswell Brewing Company    Groundswell Brewing Company
# 428     BALLAST POINT BREWING COMPANY  BALLAST POINT BREWING COMPANY
# 429  SDSU College of Extended Studies                           SDSU
#
#                            social_twitterUrl  \
# 0        https://twitter.com/SouthParkBrewCo
# 1         https://twitter.com/rouleurbrewing
# 2         https://twitter.com/rouleurbrewing
# 3         https://twitter.com/rouleurbrewing
# 4         https://twitter.com/rouleurbrewing
# ..                                       ...
# 425
# 426        https://twitter.com/5suitsbrewing
# 427      https://twitter.com/groundswellbrew
# 428  https://twitter.com/ballastpointbrewing
# 429
#
#                             social_facebookUrl  \
# 0     https://www.facebook.com/southparkbrewco
# 1      https://www.facebook.com/rouleurbrewing
# 2      https://www.facebook.com/rouleurbrewing
# 3      https://www.facebook.com/rouleurbrewing
# 4      https://www.facebook.com/rouleurbrewing
# ..                                         ...
# 425         https://www.facebook.com/taproomnp
# 426  https://www.facebook.com/fivesuitsbrewing
# 427   https://www.facebook.com/groundswellbrew
# 428     https://www.facebook.com/BallastPoint/
# 429
#
#                                social_instagramUrl social_untappdId  \
# 0       https://www.instagram.com/southparkbrewco/           189064
# 1        https://www.instagram.com/rouleurbrewing/           332529
# 2        https://www.instagram.com/rouleurbrewing/           332529
# 3        https://www.instagram.com/rouleurbrewing/           332529
# 4        https://www.instagram.com/rouleurbrewing/           332529
# ..                                             ...              ...
# 425        https://www.instagram.com/taproombeerco
# 426    https://www.instagram.com/fivesuitsbrewing/
# 427      https://www.instagram.com/groundswellbrew
# 428  https://www.instagram.com/ballastpointbrewing
# 429
#
#            lat         lng                      coords  \
# 0    32.721667 -117.130113  [-117.1301127, 32.7216668]
# 1    33.134462 -117.269810  [-117.2698102, 33.1344625]
# 2    33.128196 -117.260355   [-117.260355, 33.1281963]
# 3    33.122610 -117.079242  [-117.0792423, 33.1226102]
# 4    33.132775 -117.310714   [-117.3107141, 33.132775]
# ..         ...         ...                         ...
# 425  32.755364 -117.143779  [-117.1437794, 32.7553645]
# 426  33.148874 -117.221588  [-117.2215877, 33.1488745]
# 427  32.830799 -116.976369  [-116.9763687, 32.8307987]
# 428  32.887957 -117.157909  [-117.1579086, 32.8879565]
# 429  32.772001 -117.072697  [-117.0726966, 32.7720012]
#
#                              street  ...  \
# 0                      1517 30th St  ...
# 1    5840 El Camino Real, Suite 101  ...
# 2               6133 Innovation Way  ...
# 3                  237 E. Grand Ave  ...
# 4             5420 Grand Pacific Dr  ...
# ..                              ...  ...
# 425              2000 El Cajon Blvd  ...
# 426           2575 Pioneer Ave #104  ...
# 427           10151 Prospect Avenue  ...
# 428                 9045 Carrol Way  ...
# 429            5500 Campanile Drive  ...
#
#                                          website                  uuid  \
# 0               http://www.southparkbrewing.com/          WyBROCGvMw52
# 1                     http://rouleurbrewing.com/          mq5pOQdvyAmg
# 2                     http://rouleurbrewing.com/          mq5pOQdvyAmg
# 3                     http://rouleurbrewing.com/          mq5pOQdvyAmg
# 4                     http://rouleurbrewing.com/          mq5pOQdvyAmg
# ..                                           ...                   ...
# 425                     http://taproombeerco.com  faa935e61353b8b9c307
# 426                       https://fivesuits.com/  6bd92692b0c4e459a265
# 427                      www.groundswellbrew.com  6ec3a7ed398fb6bf0df2
# 428                         www.ballastpoint.com  9a94f9107885312a7f72
# 429  https://www.neverstoplearning.net/craftbeer  5d11ff6ccfd4a0e2dd25
#
#                                               logo_url profile_location  \
# 0    https://s3-us-west-1.amazonaws.com/paradeigm-s...             True
# 1    https://s3-us-west-1.amazonaws.com/sdbeer2/llb...             True
# 2    https://s3-us-west-1.amazonaws.com/sdbeer2/llb...            False
# 3    https://s3-us-west-1.amazonaws.com/sdbeer2/llb...            False
# 4    https://s3-us-west-1.amazonaws.com/sdbeer2/llb...            False
# ..                                                 ...              ...
# 425  https://s3-us-west-1.amazonaws.com/paradeigm-s...             True
# 426  https://s3-us-west-1.amazonaws.com/paradeigm-s...             True
# 427  https://s3-us-west-1.amazonaws.com/paradeigm-s...             True
# 428  https://s3-us-west-1.amazonaws.com/paradeigm-s...             True
# 429  https://s3-us-west-1.amazonaws.com/paradeigm-s...            False
#
#      tag_dogFriendly  tag_familyFriendly  tag_foodService tag_foodTrucks  \
# 0               True                True             True          False
# 1               True                True            False           True
# 2              False               False            False          False
# 3              False               False            False          False
# 4              False               False            False          False
# ..               ...                 ...              ...            ...
# 425             True                True             True          False
# 426            False               False            False          False
# 427             True                True            False           True
# 428             True                True             True          False
# 429            False               False            False          False
#
#     tag_growlerFills tag_over21
# 0               True      False
# 1               True      False
# 2              False      False
# 3              False      False
# 4              False      False
# ..               ...        ...
# 425             True      False
# 426            False      False
# 427             True      False
# 428             True      False
# 429            False      False
#
# [430 rows x 27 columns]

# %%
df[(df['tag_dogFriendly'] == True) & (df['tag_familyFriendly'] == False)]
# Out:
#                 name_brewery                       name_location  \
# 110              Bottlecraft          Bottlecraft — Solana Beach
# 113              Bottlecraft          Bottlecraft — Little Italy
# 114              Bottlecraft       Bottlecraft — Sorrento Valley
# 259  Belching Beaver Brewery  Belching Beaver Brewery North Park
# 309           Knotty Brewing                  Knotty Brewing Co.
# 315   Arcana Brewing Company              Arcana Brewing Company
# 366                Live Wire                           Live Wire
# 379      Rose's Tasting Room                 Rose's Tasting Room
# 381        Tap That Tap Room                   Tap That Tap Room
#
#                            social_twitterUrl  \
# 110          https://twitter.com/bottlecraft
# 113          https://twitter.com/bottlecraft
# 114          https://twitter.com/bottlecraft
# 259
# 309        https://twitter.com/knottybrewing
# 315        https://twitter.com/ArcanaBrewing
# 366  https://twitter.com/livewirebar?lang=en
# 379
# 381            https://twitter.com/TapThatSD
#
#                                     social_facebookUrl  \
# 110               https://www.facebook.com/Bottlecraft
# 113               https://www.facebook.com/Bottlecraft
# 114               https://www.facebook.com/Bottlecraft
# 259  https://www.facebook.com/pages/The-Belching-Be...
# 309          https://www.facebook.com/knottybrewingco/
# 315             https://www.facebook.com/ArcanaBrewing
# 366              https://www.facebook.com/livewirebar/
# 379         https://www.facebook.com/RosesTastingRoom/
# 381        https://www.facebook.com/tapthatkeg?fref=ts
#
#                                social_instagramUrl social_untappdId  \
# 110         https://www.instagram.com/bottlecraft/
# 113         https://www.instagram.com/bottlecraft/
# 114         https://www.instagram.com/bottlecraft/
# 259             https://twitter.com/belchingbeaver            43025
# 309       https://www.instagram.com/knottybrewing/           276993
# 315             http://instagram.com/arcanabrewing            30892
# 366   https://www.instagram.com/livewirebar/?hl=en
# 379  https://www.instagram.com/roses_tasting_room/
# 381
#
#            lat         lng                  street          city       state  \
# 110  32.986173 -117.271078           437 S Hwy 101  Solana Beach  California
# 113  32.728049 -117.170413       2252 India Street     San Diego  California
# 114  32.905022 -117.228892    11055 Roselle Street     San Diego  California
# 259  32.754750 -117.130072        4223 30th Street     San Diego  California
# 309  32.711777 -117.156852       842 Market Street     San Diego  California
# 315  33.140246 -117.273870         5621 Palmer Way      Carlsbad  California
# 366  32.754955 -117.142371      2103 El Cajon Blvd     San Diego  California
# 379  32.754923 -117.197624  2754 Calhoun St. Ste G     San Diego  California
# 381  33.215954 -117.350182   3207 Roymar Rd, Ste E     Oceanside  California
#
#     country  tag_dogFriendly  tag_familyFriendly  tag_foodService  \
# 110      US             True               False             True
# 113      US             True               False            False
# 114      US             True               False            False
# 259      US             True               False            False
# 309      US             True               False            False
# 315      US             True               False            False
# 366      US             True               False            False
# 379      US             True               False            False
# 381      US             True               False            False
#
#      tag_foodTrucks  tag_growlerFills  tag_over21
# 110           False             False        True
# 113           False             False        True
# 114           False             False        True
# 259            True              True       False
# 309           False              True        True
# 315            True              True        True
# 366           False             False       False
# 379           False             False       False
# 381            True             False       False

# %%
df[(df['deactivated'] == False) & (df['visible'] == True) & (df['profile_location'] == True)]
# Out:
#                    name_brewery  \
# 0    South Park Brewing Company
# 1       Rouleur Brewing Company
# 5             Thorn Brewing Co.
# 6             Thorn Brewing Co.
# 9             Thorn Brewing Co.
# ..                          ...
# 172              The Lost Abbey
# 173              The Lost Abbey
# 174       Duck Foot Brewing Co.
# 176       Duck Foot Brewing Co.
# 180           Jacked Up Brewery
#
#                                          name_location  \
# 0                           South Park Brewing Company
# 1                              Rouleur Brewing Company
# 5                     Thorn Brewing Co. - Barrio Logan
# 6                                 Thorn Street Brewery
# 9                  Thorn Brewing Co. - Mission Hills
# ..                                                 ...
# 172               The Lost Abbey, Cardiff Confessional
# 173                         The Lost Abbey, San Marcos
# 174  Duck Foot Brewing Co. Taproom & Brewery | Miramar
# 176  Duck Foot Brewing Co. Taproom & Kitchen | East...
# 180                                  Jacked Up Brewery
#
#                        social_twitterUrl  \
# 0    https://twitter.com/SouthParkBrewCo
# 1     https://twitter.com/rouleurbrewing
# 5     https://twitter.com/ThornStBrewery
# 6     https://twitter.com/ThornStBrewery
# 9     https://twitter.com/ThornStBrewery
# ..                                   ...
# 172        https://twitter.com/lostabbey
# 173        https://twitter.com/lostabbey
# 174     https://twitter.com/duckfootbeer
# 176     https://twitter.com/duckfootbeer
# 180
#
#                             social_facebookUrl  \
# 0     https://www.facebook.com/southparkbrewco
# 1      https://www.facebook.com/rouleurbrewing
# 5     https://www.facebook.com/thornstreetbrew
# 6     https://www.facebook.com/thornstreetbrew
# 9     https://www.facebook.com/thornstreetbrew
# ..                                         ...
# 172    https://www.facebook.com/port.lostabbey
# 173    https://www.facebook.com/port.lostabbey
# 174     https://www.facebook.com/DuckFootBeer/
# 176     https://www.facebook.com/DuckFootBeer/
# 180  https://www.facebook.com/JackedUpBrewery/
#
#                               social_instagramUrl social_untappdId        lat  \
# 0      https://www.instagram.com/southparkbrewco/           189064  32.721667
# 1       https://www.instagram.com/rouleurbrewing/           332529  33.134462
# 5    https://www.instagram.com/thornstreetbrewery            47013  32.702261
# 6    https://www.instagram.com/thornstreetbrewery            47013  32.739399
# 9    https://www.instagram.com/thornstreetbrewery            47013  32.750411
# ..                                            ...              ...        ...
# 172                http://instagram.com/lostabbey             2712  33.022186
# 173                http://instagram.com/lostabbey             2712  33.141627
# 174       https://www.instagram.com/duckfootbeer/           105084  32.885499
# 176       https://www.instagram.com/duckfootbeer/           105084  32.710897
# 180    https://www.instagram.com/jackedupbrewery/           319612  33.117309
#
#             lng                      coords                          street  \
# 0   -117.130113  [-117.1301127, 32.7216668]                    1517 30th St
# 1   -117.269810  [-117.2698102, 33.1344625]  5840 El Camino Real, Suite 101
# 5   -117.147937   [-117.1479369, 32.702261]            1735 National Avenue
# 6   -117.125499  [-117.1254989, 32.7393987]               3176 Thorn Street
# 9   -117.172590  [-117.1725897, 32.7504106]            4026 Hawk St Suite A
# ..          ...                         ...                             ...
# 172 -117.282216   [-117.282216, 33.0221861]              2007 San Elijo Ave
# 173 -117.149267  [-117.1492671, 33.1416273]          155 Mata Way, Ste #104
# 174 -117.156392  [-117.1563922, 32.8854988]  8920 Kenamar Drive, Suite #210
# 176 -117.154195  [-117.1541951, 32.7108972]     550 Park Boulevard Ste 2104
# 180 -117.091742  [-117.0917422, 33.1173091]              800 W Grand Avenue
#
#      ...                           website          uuid  \
# 0    ...  http://www.southparkbrewing.com/  WyBROCGvMw52
# 1    ...        http://rouleurbrewing.com/  mq5pOQdvyAmg
# 5    ...                 http://thorn.beer  iEulEhPtjS6G
# 6    ...                 http://thorn.beer  iEulEhPtjS6G
# 9    ...                 http://thorn.beer  iEulEhPtjS6G
# ..   ...                               ...           ...
# 172  ...             http://lostabbey.com/  j2eGt62XrP7f
# 173  ...             http://lostabbey.com/  j2eGt62XrP7f
# 174  ...          http://duckfootbeer.com/  k3yuuQ3DADQK
# 176  ...          http://duckfootbeer.com/  k3yuuQ3DADQK
# 180  ...        http://jackedupbrewery.com  tURWWI172RvW
#
#                                               logo_url profile_location  \
# 0    https://s3-us-west-1.amazonaws.com/paradeigm-s...             True
# 1    https://s3-us-west-1.amazonaws.com/sdbeer2/llb...             True
# 5    https://s3-us-west-1.amazonaws.com/sdbeer2/oDP...             True
# 6    https://s3-us-west-1.amazonaws.com/sdbeer2/oDP...             True
# 9    https://s3-us-west-1.amazonaws.com/sdbeer2/oDP...             True
# ..                                                 ...              ...
# 172  https://s3-us-west-1.amazonaws.com/sdbeer2/qly...             True
# 173  https://s3-us-west-1.amazonaws.com/sdbeer2/qly...             True
# 174  https://s3-us-west-1.amazonaws.com/sdbeer2/VsK...             True
# 176  https://s3-us-west-1.amazonaws.com/sdbeer2/VsK...             True
# 180  https://s3-us-west-1.amazonaws.com/sdbeer2/agL...             True
#
#      tag_dogFriendly  tag_familyFriendly  tag_foodService tag_foodTrucks  \
# 0               True                True             True          False
# 1               True                True            False           True
# 5               True                True            False           True
# 6               True                True            False           True
# 9               True                True            False          False
# ..               ...                 ...              ...            ...
# 172             True                True            False          False
# 173            False                True            False           True
# 174             True                True            False          False
# 176             True                True             True          False
# 180             True                True            False           True
#
#     tag_growlerFills tag_over21
# 0               True      False
# 1               True      False
# 5               True      False
# 6               True      False
# 9               True      False
# ..               ...        ...
# 172             True      False
# 173             True      False
# 174             True      False
# 176             True      False
# 180            False      False
#
# [99 rows x 27 columns]

# %%
# df.to_csv('data/sd_brewers_guild.csv')

# %%
# Initialize the SD map
sdMap = folium.Map(location=[32.71533, -117.15726], tiles='Stamen Toner', zoom_start=9)
dogFriendly_df = df[df['tag_dogFriendly'] == True]

# For each row in the dataset, plot the corresponding latitude and longitude on the map
for i,row in dogFriendly_df.iterrows():
    folium.CircleMarker((row.lat,row.lng), radius=3, weight=2, color='red', fill_color='red', fill_opacity=.5).add_to(sdMap)

#add the heatmap. The core parameters are:
#--data: a list of points of the form (latitude, longitude) indicating locations of Starbucks stores
#--radius: how big each circle will be around each Starbucks store
#--blur: the degree to which the circles blend together in the heatmap

sdMap.add_child(plugins.HeatMap(data=dogFriendly_df[['lat', 'lng']].to_numpy(), radius=10, blur=3))

# Save the map as an html
# sdMap.save('sdHeatmap.html')
sdMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
